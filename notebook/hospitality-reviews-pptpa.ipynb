# %% [markdown]
# # Step 1 : Install required **Libraries**

# %%
# Installing all the necessary libraries for embedding, clustering, and labeling review data
# !pip install -q sentence-transformers transformers faiss-cpu scikit-learn pandas
# !pip install -q transformers
# !pip install hf_xet
# Out:
# Requirement already satisfied: hf_xet in /usr/local/lib/python3.11/dist-packages (1.0.3)

# %% [markdown]
# # STEP 2: Import Libraries

# %%
# Importing required libraries for text processing, clustering, and modeling
import json
import re
import csv
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from transformers import T5Tokenizer, T5ForConditionalGeneration
# for fast vector similarity search
import faiss

# %%
from transformers import pipeline

zero_shot = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

candidate_labels = [
    "cleanliness", "location", "value", "service", "food_availability",
    "crowd_level", "pricing", "queue_fairness", "park_experience",
    "emotional_impact", "attractions", "overall_experience"
]
# Out:
# Device set to use cpu

# %% [markdown]
# # STEP 3: Load and clean Dataset

# %%
# Load the Excel file containing user reviews
# Remove any rows with missing review text to ensure clean input
# Extract reviews as a list
df = pd.read_excel('/kaggle/input/test-data/Dataset_Kaggle_project.xlsx', engine='openpyxl')
df = df.dropna(subset=["Review"])
texts = df["Review"].tolist()

# %% [markdown]
# # STEP 4: Load pre-trained available AI Models

# %%
# Load SentenceTransformer model for embeddings
# Load FLAN-T5 for prompt-based text generation (cluster labeling)
embed_model = SentenceTransformer('all-MiniLM-L6-v2')
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-base")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-base")

# %% [markdown]
# # STEP 5: Create Embeddings and Index for similarity search (FAISS) #

# %%
# Convert reviews into embeddings using a pretrained model

embeddings = embed_model.encode(texts, show_progress_bar=True)
dimension = embeddings.shape[1]
# Build a FAISS index for fast similarity querying
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # STEP 6:  Clause-Level Categorization - Text Splitting & Preprocessing #

# %%
# Utility to break down long reviews into shorter, semantically meaningful clauses
# Helps improve clustering and labeling accuracy
def split_review_into_clauses(review):
    raw_clauses = re.split(r'[.!?;]+', review)
    return [c.strip() for c in raw_clauses if len(c.strip().split()) >= 5]

# %% [markdown]
# # Step 7 :Clause Categorization & Sentiment Detection

# %%
import re
import json
from transformers import pipeline

# Load external rule files (uploaded to Kaggle)
with open("/kaggle/input/d/taniaparisi/sentiment-overrides/category_rules.json") as f:
    CATEGORY_RULES = json.load(f)

with open("/kaggle/input/d/taniaparisi/sentiment-overrides/sentiment_overrides.json") as f:
    SENTIMENT_OVERRIDES = json.load(f)

# Load sentiment model
sentiment_model = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
CONFIDENCE_THRESHOLD = 0.6
DEBUG = False  # Toggle debug prints

# Match keywords inside a clause
def match_keywords(clause, keywords):
    return any(k in clause for k in keywords)

# Analyze a clause for category and sentiment
def analyze_clause(clause):
    clause = clause.strip().lower()
    entry = {"text": clause, "category_sentiments": {}}

    # Match categories
    for category, keywords in CATEGORY_RULES.items():
        if match_keywords(clause, keywords):
            entry["category_sentiments"][category] = None  # sentiment to be added

    # Sentiment override
    overridden = None
    for label, phrases in SENTIMENT_OVERRIDES.items():
        if match_keywords(clause, phrases):
            overridden = label
            break

    # If no categories matched, assign 'uncategorized'
    if not entry["category_sentiments"]:
        entry["category_sentiments"]["uncategorized"] = None

    # Run sentiment model
    try:
        result = sentiment_model(clause)[0]
        model_label = result["label"].lower()
        score = result["score"]

        sentiment = (
            "neutral" if score < CONFIDENCE_THRESHOLD
            else "positive" if "positive" in model_label
            else "negative" if "negative" in model_label
            else "neutral"
        )
    except Exception as e:
        print(f"Sentiment analysis failed for: {clause}\nError: {e}")
        sentiment = "neutral"

    # Assign sentiment per category
    final_sentiment = overridden if overridden else sentiment
    for cat in entry["category_sentiments"].keys():
        entry["category_sentiments"][cat] = final_sentiment

    return entry


# Categorize a list of reviews
def categorize_reviews_multiclause(review_list):
    categorized = []
    for review in review_list:
        clauses = split_review_into_clauses(review)
        for clause in clauses:
            if clause.strip():
                result = analyze_clause(clause)
                if DEBUG:
                    cat_sent = ", ".join([f"{k}: {v}" for k, v in result["category_sentiments"].items()])
                    print(f"DEBUG → Clause: {clause} → {cat_sent}")
                categorized.append(result)
    return categorized
# Out:
# Device set to use cpu

# %% [markdown]
# # Step 8: Cluster the Categorized Clauses

# %%
# Using KMeans to group similar review clauses together based on semantic embeddings
def cluster_clauses(categorized_reviews, n_clusters=8):
    clause_texts = [entry["text"] for entry in categorized_reviews]
    clause_embeddings = embed_model.encode(clause_texts, show_progress_bar=True)

    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(clause_embeddings)

    clusters = {}
    for i, label in enumerate(labels):
        clusters.setdefault(label, []).append(clause_texts[i])
    
    return clusters

# %% [markdown]
# # Step 9: Define Cluster Label to Category Mapping

# %%
# This dictionary maps generated FLAN-T5 cluster labels to standardized categories
cluster_label_to_category = {
    "wait time": "wait_times",
    "hot dogs": "food_availability",
    "great hotel in a great location": "hotel_quality",
    "the disneyland parks": "park_experience",
    "the line was longer than the ride's lines": "queue_fairness",
    "the price is high": "pricing",
    "love this place always when we are there is magical": "magical_experience",
    "a mediocre experience": "overall_experience",
    "a lot of rides": "attractions",
    "the best hotel in vegas": "emotional_impact",
}

# %% [markdown]
# # Step 10 :  Label Clusters with FLAN-T5

# %%
# For each cluster, FLAN-T5 generates a human-readable label summarizing the common theme
def label_clusters_with_flan(clusters, tokenizer, model, max_examples_per_cluster=5):
    labeled_clusters = {}

    for cluster_id, samples in clusters.items():
        if len(samples) < 2:
            print(f"\n⏭️ Skipping Cluster {cluster_id} (not enough samples)")
            continue

        prompt = "Given the following hotel review statements, suggest a short topic label (1–3 words):\n\n"
        for i, clause in enumerate(samples[:max_examples_per_cluster]):
            prompt += f"{i+1}. {clause.strip()}\n"
        prompt += "\nLabel:"

        inputs = tokenizer(prompt, return_tensors='pt', truncation=True, max_length=512)
        outputs = model.generate(**inputs, max_new_tokens=10)
        label = tokenizer.decode(outputs[0], skip_special_tokens=True).split("\n")[0].split(".")[0].strip().lower()
        category = cluster_label_to_category.get(label, "uncategorized")

        labeled_clusters[label] = {"category": category, "clauses": samples}
        print(f"\n🏷️ Cluster {cluster_id} → {label} → Category: {category}")
        for s in samples:
            print(f" - {s}")
    
    return labeled_clusters

# %% [markdown]
# # Step 11: Assign Cluster Categories to Reviews

# %%
def assign_cluster_categories_to_reviews(categorized_reviews, labeled_clusters):
    # Build lookup: clause text (lowercased) → inferred category (cluster label)
    clause_to_category = {
        text.strip().lower(): label
        for label, cluster in labeled_clusters.items()
        for text in cluster
    }

    for entry in categorized_reviews:
        clause_text = entry["text"].strip().lower()
        inferred_cat = clause_to_category.get(clause_text)

        # Initialize if not present
        if "category_sentiments" not in entry:
            entry["category_sentiments"] = {}

        current_cats = entry["category_sentiments"].keys()

        # Only assign if it's completely uncategorized or only has 'uncategorized'
        if inferred_cat and (not current_cats or current_cats == {"uncategorized"}):
            sentiment = entry.get("sentiment", "neutral")
            entry["category_sentiments"] = {inferred_cat: sentiment}
            entry["categories"] = [inferred_cat]  # Optional for compatibility

    return categorized_reviews

# %% [markdown]
# # Generate summary and categorize Top reviews based on a query

# %%
def debug_grounded_summary_steps(
    query,
    top_k_reviews,
    categorized_reviews,
    category_counts,
    sentiment_counts,
    prompt,
    summary
):
    print("\n🔍 Step 1: Top-k Retrieved Reviews:")
    for i, review in enumerate(top_k_reviews, 1):
        print(f"{i}. {review}")

    print("\n🧩 Step 2: Categorized Clauses:")
    for item in categorized_reviews:
        print(f"Text: {item['text']}, Categories: {item['categories']}, Sentiment: {item['sentiment']}")

    print("\n📊 Step 3: Stats Summary:")
    print("Top Categories:", category_counts)
    print("Sentiment Counts:", sentiment_counts)

    print("\n📚 Step 4: Prompt Sent to FLAN:")
    print(prompt)

    print("\n📝 Step 4: Generated Summary:")
    print(summary)

# %%
def grounded_summary(query, k=20, debug=False):
    from collections import Counter

    # Step 1: Retrieve top-k most semantically similar reviews
    query_embedding = embed_model.encode([query])
    D, I = index.search(query_embedding, k)
    top_k_reviews = [texts[i] for i in I[0]]

    if debug:
        print("🔍 Step 1: Top-k Retrieved Reviews:")
        for i, review in enumerate(top_k_reviews, 1):
            print(f"{i}. {review}")

    # Step 2: Categorize clauses
    categorized_reviews = categorize_reviews_multiclause(top_k_reviews)

    if debug:
        print("\n🧩 Step 2: Categorized Clauses:")
        for item in categorized_reviews:
            print(f"Text: {item['text']}, Category Sentiments: {item.get('category_sentiments', {})}")


    # Step 3: Stats
    all_categories = [
        cat.lower()
        for review in categorized_reviews
        for cat in review["category_sentiments"].keys()
        if cat.lower() != "uncategorized"
        ]
    
    all_sentiments = [
        sentiment
        for review in categorized_reviews
        for sentiment in review["category_sentiments"].values()
        if sentiment
    ]

    category_counts = Counter(all_categories)
    sentiment_counts = Counter(all_sentiments)

    total_cats = len(all_categories)
    top_categories = category_counts.most_common(3)
    top_categories_str = ", ".join([
        f"{cat} ({(count/total_cats)*100:.0f}%)" for cat, count in top_categories
    ])

    total_sentiments = len(all_sentiments)
    positive_pct = (sentiment_counts["positive"] / total_sentiments) * 100 if total_sentiments else 0
    negative_pct = (sentiment_counts["negative"] / total_sentiments) * 100 if total_sentiments else 0
    neutral_pct = (sentiment_counts["neutral"] / total_sentiments) * 100 if total_sentiments else 0

    top_sentiment = max(sentiment_counts, key=sentiment_counts.get) if sentiment_counts else "neutral"

    if debug:
        print("\n📊 Step 3: Stats Summary:")
        print(f"Top Categories: {top_categories_str}")
        print(f"Sentiment → Positive: {positive_pct:.0f}%, Neutral: {neutral_pct:.0f}%, Negative: {negative_pct:.0f}%")

    # Step 4: Prepare Summary Input
    # Prepare cleaner, focused input using only clause texts
    positive_clauses = [r["text"] for r in categorized_reviews if "positive" in r["category_sentiments"].values()]
    negative_clauses = [r["text"] for r in categorized_reviews if "negative" in r["category_sentiments"].values()]
    neutral_clauses = [r["text"] for r in categorized_reviews if "neutral" in r["category_sentiments"].values()]

    
    # Sample balance (optional: tune these numbers)
    clauses_to_use = positive_clauses[:10] + negative_clauses[:10] + neutral_clauses[:2]
    review_text = " ".join(clauses_to_use)
    
    # Optimized prompt
    prompt = (
        "You are summarizing visitor reviews about Disneyland Parks.\n"
        "Summarize what guests liked 👍, disliked 👎, and suggest improvements 🛠️.\n"
        "Use bullet points and avoid repetition.\n\n"
        "Examples:\n"
        "- 👍 Friendly staff, clean rooms, and great location.\n"
        "- 👎 Long wait times and high food prices.\n"
        "- 🛠️ Improve queue management and offer more food variety.\n\n"
        f"Guest comments:\n{review_text}\n\n"
        "Summary:"
    )




    if debug:
        print("\n🧠 Step 4: Prompt Sent to FLAN:")
        print(prompt)

    # Step 5: Generate Summary
    inputs = tokenizer(prompt, return_tensors='pt', truncation=True, max_length=512)
    outputs = model.generate(**inputs, max_new_tokens=200, num_beams=4, no_repeat_ngram_size=4, early_stopping=True)
    summary = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

    # Fallback if too short
    if len(summary.split()) < 10:
        summary += (
            "\n- 👎 Some guests noted long wait times and expensive food.\n"
            "- 🛠️ Improvements in food service speed and queue fairness recommended."
        )

    if debug:
        print("\n📝 Step 5: FLAN Summary:")
        print(summary)

    # Final Enriched Output
    enriched_summary = (
        f"{summary}\n\n"
        f"🗂️ Top categories: {top_categories_str}\n"
        f"😊 Sentiment breakdown → Positive: {positive_pct:.0f}%, Neutral: {neutral_pct:.0f}%, Negative: {negative_pct:.0f}%\n"
        f"💬 Overall sentiment: {top_sentiment}"
    )

    return {
        "query": query,
        "summary": enriched_summary,
        "top_k_reviews": top_k_reviews,
        "categorized_reviews": categorized_reviews
    }

# %% [markdown]
# # Step 12 : Run the full pipeline

# %%
# 1. Run the grounding/summarization module to extract relevant reviews
output = grounded_summary("Disneyland Parks", k=20)

# 2. Cluster the clauses from those reviews
clusters = cluster_clauses(output["categorized_reviews"], n_clusters=8)

# 3. Generate human-readable labels for the clusters
labeled_clusters = label_clusters_with_flan(clusters, tokenizer, model)

# 4. Assign those labels/categories back to the individual clause entries
output["categorized_reviews"] = assign_cluster_categories_to_reviews(
    output["categorized_reviews"], labeled_clusters
)

# 5. Save labeled clusters in the output for export
output["labeled_clusters"] = labeled_clusters
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 🏷️ Cluster 2 → great hotel in a great location → Category: hotel_quality
#  - great hotel in a great location
#  - it was great value for money – proper budget accommodation with everything we needed right there on site
#  - would definitely recommend if you're after a simple, well-positioned place to stay without breaking the bank
#  - the hotel is clean and well presented
#  - the hotel itself is in a great location, but is in need of some renovation which is a shame given the price
#  - overall though, we would stay again and would recommend it
#  - rooms are old and in bad shape
#  - hotel is 3 star hotel max but at the price of a 5 star hotel
#
# 🏷️ Cluster 4 → disneyland parish → Category: uncategorized
#  - staff are really friendly and it is really easy to get to from the disneyland parks
#  - we had a lovely stay at the davey crocket ranch at disneyland parish
#  - the location was spot-on, making it easy to get around and enjoy the parks
#  - the smallest of all disney parks
#  - the total area is too small and always crowded, every other second you run into strangers because of how small the spaces and streets are
#  - and the lines are not well designed- most of them are outside without any decoration and entertainment
#  - not to mention there were only like 10 people in front of us, which means it takes about 10 minutes to get an order per person
#  - it's is a shame and disrespect for the visitors expensive time in the park
#  - the staff were very friendly and efficient
#  - staff is not very attentive
#
# 🏷️ Cluster 3 → the magic kingdom → Category: uncategorized
#  - you can either walk 15-20 minutes or get a 5 minute shuttle (free)
#  - huge crowd, it's hard to finish 1 park in 1 day
#  - at least take 3 days for 2 parks if you want to finish everything
#  - every ride has a 50 minutes wait time at best, most of them didn't even last less then an hour
#  - the park only offers a few rides, and while we were waiting in line for them 3 of the rides had technical issues that made the lines even 15-40 minutes longer then the wait time written
#  - in order to enjoy the park you need the premier access which costs more then the park ticket itself, which make it unfair to people who don't have money laying around waiting to be spent
#
# 🏷️ Cluster 7 → i love this hotel → Category: uncategorized
#  - we were lucky with the weather too, which made the whole trip even better
#  - absolutely magical, our grandchildren were totally overwhelmed with excitement
#  - take your kids and enjoy watching them
#  - where the dreams come true
#  - love this place always when we are there is magical
#  - hard work at our age but worth all the aches to see the grandkids faces light up
#  - kids paradise, just remember your credit card and your backup credit card
#
# 🏷️ Cluster 5 → the line at the magic kingdom → Category: uncategorized
#  - the length of the lines is caused by the slow phase they let you into the rides
#  - not to mention that the "premier access" line is always full and the workers let them in the ride in an unfair way
#  - most of the riders in each train or car every time are express pass holders, which makes it unfair to the people standing in line for hours without making any progress due to that system
#  - the line was longer than the ride's lines
#
# 🏷️ Cluster 0 → a hotel experience → Category: uncategorized
#  - every restaurant and even food track had an hour long wait line with not enough places to sit at
#  - in conclusion- our entire experience was wait time after wait time and unprofessional amount of
#
# 🏷️ Cluster 6 → disney → Category: uncategorized
#  - but like the rest of disney the prices are eye watering £££££
#  - rides and place is fantastic, prices are jaw dropping ££££££
#  - the prices are sky high
#
# 🏷️ Cluster 1 → food track → Category: uncategorized
#  - after spending hours standing in the long overcrowded lines in the park, we were hoping to get something to eat
#  - there were barely any options in the park, and we naively wanted to eat a hot dog so we went to this food track
#  - it took us over an hour to get two pre-made hot dogs (that tasted average)
#  - everything in this track was pre made- ice cream, brownies etc
#  - i had restaurants who served twice as faster
#  - we opted not to eat in the hotel, aside from 2 breakfasts, as choice wasn’t great for the price
#  - the manhattan restaurant at the new york hotel was cheaper to feed a family of 4
#  - the food is delicious at every point,

# %% [markdown]
# # Check results for me

# %%
output = grounded_summary("Disneyland Paris", k=10, debug=True)
print("🔍 Summary:")
print(output["summary"])
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 🔍 Step 1: Top-k Retrieved Reviews:
# 1. Great hotel in a great location. Staff are really friendly and it is really easy to get to from the Disneyland Parks. You can either walk 15-20 minutes or get a 5 minute shuttle (free).
# 2. We had a lovely stay at the Davey Crocket ranch at Disneyland Parish! It was great value for money – proper budget accommodation with everything we needed right there on site. The location was spot-on, making it easy to get around and enjoy the parks. We were lucky with the weather too, which made the whole trip even better. Would definitely recommend if you're after a simple, well-positioned place to stay without breaking the bank.
# 3. Best place on earth
# 4. The hotel is clean and well presented.
# But like the rest of Disney the prices are eye watering £££££
# 5. Huge crowd, it's hard to finish 1 park in 1 day. At least take 3 days for 2 parks if you want to finish everything
# 6. Rides and place is fantastic, prices are jaw dropping ££££££
# 7. The smallest of all Disney parks. The total area is too small and always crowded, every other second you run into strangers because of how small the spaces and streets are. Every ride has a 50 minutes wait time at best, most of them didn't even last less then an hour. And the lines are not well designed- most of them are outside without any decoration and entertainment. The length of the lines is caused by the slow phase they let you into the rides. Not to mention that the "premier access" line is always full and the workers let them in the ride in an unfair way. Most of the riders in each train or car every time are express pass holders, which makes it unfair to the people standing in line for hours without making any progress due to that system. The park only offers a few rides, and while we were waiting in line for them 3 of the rides had technical issues that made the lines even 15-40 minutes longer then the wait time written. In order to enjoy the park you need the premier access which costs more then the park ticket itself, which make it unfair to people who don't have money laying around waiting to be spent. Every restaurant and even food track had an hour long wait line with not enough places to sit at. In conclusion- our entire experience was wait time after wait time and unprofessional amount of .malfunctions
# 8. Absolutely magical, our grandchildren were totally overwhelmed with excitement.
# Superb!
# 9. ?wiat Marze? ??to w?a?nie tam! Where the dreams come true ?? love this place always when we are there is magical ????????????????? The food is delicious at every point,??????????????????????????
# 10. After spending hours standing in the long overcrowded lines in the park, we were hoping to get something to eat. There were barely any options in the park, and we naively wanted to eat a hot dog so we went to this food track. The line was longer than the ride's lines. It took us over an hour to get two pre-made hot dogs (that tasted average). Everything in this track was pre made- ice cream, brownies etc. not to mention there were only like 10 people in front of us, which means it takes about 10 minutes to get an order per person. It's is a shame and disrespect for the visitors expensive time in the park. Please do better. I had restaurants who served twice as faster.
#
# 🧩 Step 2: Categorized Clauses:
# Text: great hotel in a great location, Category Sentiments: {'location': 'positive', 'food_availability': 'positive'}
# Text: staff are really friendly and it is really easy to get to from the disneyland parks, Category Sentiments: {'location': 'positive', 'service': 'positive'}
# Text: you can either walk 15-20 minutes or get a 5 minute shuttle (free), Category Sentiments: {'location': 'negative'}
# Text: we had a lovely stay at the davey crocket ranch at disneyland parish, Category Sentiments: {'uncategorized': 'positive'}
# Text: it was great value for money – proper budget accommodation with everything we needed right there on site, Category Sentiments: {'value': 'positive', 'maintenance': 'positive', 'food_availability': 'positive'}
# Text: the location was spot-on, making it easy to get around and enjoy the parks, Category Sentiments: {'location': 'positive', 'overall_experience': 'positive'}
# Text: we were lucky with the weather too, which made the whole trip even better, Category Sentiments: {'food_availability': 'positive'}
# Text: would definitely recommend if you're after a simple, well-positioned place to stay without breaking the bank, Category Sentiments: {'maintenance': 'positive', 'overall_experience': 'positive'}
# Text: the hotel is clean and well presented, Category Sentiments: {'cleanliness': 'positive'}
# Text: but like the rest of disney the prices are eye watering £££££, Category Sentiments: {'value': 'negative'}
# Text: huge crowd, it's hard to finish 1 park in 1 day, Category Sentiments: {'attractions': 'negative'}
# Text: at least take 3 days for 2 parks if you want to finish everything, Category Sentiments: {'uncategorized': 'negative'}
# Text: rides and place is fantastic, prices are jaw dropping ££££££, Category Sentiments: {'value': 'positive', 'maintenance': 'positive', 'attractions': 'positive', 'overall_experience': 'positive'}
# Text: the smallest of all disney parks, Category Sentiments: {'uncategorized': 'negative'}
# Text: the total area is too small and always crowded, every other second you run into strangers because of how small the spaces and streets are, Category Sentiments: {'maintenance': 'negative', 'queue_fairness': 'negative'}
# Text: every ride has a 50 minutes wait time at best, most of them didn't even last less then an hour, Category Sentiments: {'location': 'negative', 'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: and the lines are not well designed- most of them are outside without any decoration and entertainment, Category Sentiments: {'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: the length of the lines is caused by the slow phase they let you into the rides, Category Sentiments: {'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: not to mention that the "premier access" line is always full and the workers let them in the ride in an unfair way, Category Sentiments: {'maintenance': 'negative', 'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: most of the riders in each train or car every time are express pass holders, which makes it unfair to the people standing in line for hours without making any progress due to that system, Category Sentiments: {'maintenance': 'negative', 'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: the park only offers a few rides, and while we were waiting in line for them 3 of the rides had technical issues that made the lines even 15-40 minutes longer then the wait time written, Category Sentiments: {'location': 'negative', 'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: in order to enjoy the park you need the premier access which costs more then the park ticket itself, which make it unfair to people who don't have money laying around waiting to be spent, Category Sentiments: {'value': 'negative', 'maintenance': 'negative', 'queue_fairness': 'negative', 'overall_experience': 'negative'}
# Text: every restaurant and even food track had an hour long wait line with not enough places to sit at, Category Sentiments: {'maintenance': 'negative', 'queue_fairness': 'negative', 'food_availability': 'negative'}
# Text: in conclusion- our entire experience was wait time after wait time and unprofessional amount of, Category Sentiments: {'queue_fairness': 'negative'}
# Text: absolutely magical, our grandchildren were totally overwhelmed with excitement, Category Sentiments: {'overall_experience': 'positive'}
# Text: where the dreams come true, Category Sentiments: {'overall_experience': 'positive'}
# Text: love this place always when we are there is magical, Category Sentiments: {'maintenance': 'positive', 'overall_experience': 'positive'}
# Text: the food is delicious at every point,, Category Sentiments: {'food_availability': 'positive'}
# Text: after spending hours standing in the long overcrowded lines in the park, we were hoping to get something to eat, Category Sentiments: {'queue_fairness': 'positive', 'food_availability': 'positive'}
# Text: there were barely any options in the park, and we naively wanted to eat a hot dog so we went to this food track, Category Sentiments: {'maintenance': 'negative', 'food_availability': 'negative'}
# Text: the line was longer than the ride's lines, Category Sentiments: {'attractions': 'negative', 'queue_fairness': 'negative'}
# Text: it took us over an hour to get two pre-made hot dogs (that tasted average), Category Sentiments: {'food_availability': 'negative'}
# Text: everything in this track was pre made- ice cream, brownies etc, Category Sentiments: {'maintenance': 'negative', 'food_availability': 'negative'}
# Text: not to mention there were only like 10 people in front of us, which means it takes about 10 minutes to get an order per person, Category Sentiments: {'location': 'negative'}
# Text: it's is a shame and disrespect for the visitors expensive time in the park, Category Sentiments: {'value': 'negative'}
# Text: i had restaurants who served twice as faster, Category Sentiments: {'food_availability': 'neutral'}
#
# 📊 Step 3: Stats Summary:
# Top Categories: queue_fairness (19%), maintenance (17%), food_availability (16%)
# Sentiment → Positive: 38%, Neutral: 2%, Negative: 61%
#
# 🧠 Step 4: Prompt Sent to FLAN:
# You are summarizing visitor reviews about Disneyland Parks.
# Summarize what guests liked 👍, disliked 👎, and suggest improvements 🛠️.
# Use bullet points and avoid repetition.
#
# Examples:
# - 👍 Friendly staff, clean rooms, and great location.
# - 👎 Long wait times and high food prices.
# - 🛠️ Improve queue management and offer more food variety.
#
# Guest comments:
# great hotel in a great location staff are really friendly and it is really easy to get to from the disneyland parks we had a lovely stay at the davey crocket ranch at disneyland parish it was great value for money – proper budget accommodation with everything we needed right there on site the location was spot-on, making it easy to get around and enjoy the parks we were lucky with the weather too, which made the whole trip even better would definitely recommend if you're after a simple, well-positioned place to stay without breaking the bank the hotel is clean and well presented rides and place is fantastic, prices are jaw dropping ££££££ absolutely magical, our grandchildren were totally overwhelmed with excitement you can either walk 15-20 minutes or get a 5 minute shuttle (free) but like the rest of disney the prices are eye watering £££££ huge crowd, it's hard to finish 1 park in 1 day at least take 3 days for 2 parks if you want to finish everything the smallest of all disney parks the total area is too small and always crowded, every other second you run into strangers because of how small the spaces and streets are every ride has a 50 minutes wait time at best, most of them didn't even last less then an hour and the lines are not well designed- most of them are outside without any decoration and entertainment the length of the lines is caused by the slow phase they let you into the rides not to mention that the "premier access" line is always full and the workers let them in the ride in an unfair way i had restaurants who served twice as faster
#
# Summary:
#
# 📝 Step 5: FLAN Summary:
# Friendly staff, clean rooms, and great location.  Long wait times and high food prices.  Improve queue management and offer more food variety.
# 🔍 Summary:
# Friendly staff, clean rooms, and great location.  Long wait times and high food prices.  Improve queue management and offer more food variety.
#
# 🗂️ Top categories: queue_fairness (19%), maintenance (17%), food_availability (16%)
# 😊 Sentiment breakdown → Positive: 38%, Neutral: 2%, Negative: 61%
# 💬 Overall sentiment: negative

# %%
#print("\n📄 Top Matching Reviews:")
#for review in output["top_k_reviews"]:
    #print(f"- {review}")

# %%
df_clauses = pd.DataFrame(output["categorized_reviews"])
#df_clauses.head(40)  # or display full df

# %% [markdown]
# # Step 13 :Save Output to JSON

# %%
# Save entire analysis result to a structured JSON file for further use
with open("grounded_summary.json", "w", encoding="utf-8") as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

# %% [markdown]
# # Step 14 : Export clusters to CSV

# %%
# Export clustered output to a CSV file for manual review or reporting
with open("clustered_output.csv", "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Cluster Label", "Sample Clauses"])
    for label, data in labeled_clusters.items():
        for clause in data["clauses"]:
            writer.writerow([label, clause])
